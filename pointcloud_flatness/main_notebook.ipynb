# %%
from core.demo import run_flatness_demo

# Demo
run_flatness_demo(
    baseline=0.6,      # 相机-投影仪基线 (m)
    Z0=0.2,             # 相机到玻璃平均距离 (m)
    f=800,              # 焦距 (px)
    noise=0.0002,       # 噪声幅度 (m)
    shape_type='saddle',
    scale_height=0.002,   # 曲面高度范围 (m)
)

# 或者在 Notebook 下接着放实际数据分析模块（FileUpload + process_real_data）
# Out:
# 曲面类型: saddle
# 拟合平面: z = -0.000011x + -0.000009y + 0.200082
# 平整度范围: 2.007 mm
# 平整度 RMS: 0.263 mm
# (array([[-5.00000000e-01, -4.00000000e-01,  2.44000000e-04],
#         [-4.87341772e-01, -4.00000000e-01,  2.19004006e-04],
#         [-4.74683544e-01, -4.00000000e-01,  1.94648934e-04],
#         ...,
#         [ 4.74683544e-01,  4.00000000e-01,  1.94648934e-04],
#         [ 4.87341772e-01,  4.00000000e-01,  2.19004006e-04],
#         [ 5.00000000e-01,  4.00000000e-01,  2.44000000e-04]]),
#  array([[-0.50084073, -0.40067258,  0.2005807 ],
#         [-0.48651927, -0.39932491,  0.19988109],
#         [-0.47435318, -0.39972162,  0.20005532],
#         ...,
#         [ 0.47460977,  0.39993783,  0.20016354],
#         [ 0.48683376,  0.39958303,  0.20001029],
#         [ 0.49961477,  0.39969182,  0.20008972]]),
#  array([-0.48951559,  0.20992709,  0.03556143, ..., -0.09047994,
#          0.06263229, -0.01694127]))
